# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
print(city)
# Out:
# narsaq

# %%
print(cities)
# Out:
# ['hualmay', 'emba', 'arraial do cabo', 'east london', 'ushuaia', 'kurilsk', 'zunyi', 'illoqqortoormiut', 'tasiilaq', 'avarua', 'geraldton', 'vaini', 'punta arenas', 'rikitea', 'bluff', 'capao da canoa', 'samusu', 'kodiak', 'saint anthony', 'katsuura', 'taksimo', 'portland', 'naftah', 'padre bernardo', 'aklavik', 'saleaula', 'broken hill', 'tiksi', 'cabo san lucas', 'kihei', 'azuaga', 'hermanus', 'dickinson', 'annonay', 'leningradskiy', 'riberalta', 'laguna', 'chuy', 'kavaratti', 'airai', 'bredasdorp', 'yellowknife', 'batemans bay', 'barentsburg', 'cape town', 'chudniv', 'mataura', 'taolanaro', 'hilo', 'albany', 'nikolskoye', 'jamestown', 'sinkat', 'upernavik', 'santa cruz', 'mazatlan', 'sawakin', 'banda aceh', 'havelock', 'labuhan', 'vila franca do campo', 'auki', 'hambantota', 'boende', 'busselton', 'loa janan', 'mahebourg', 'norman wells', 'beringovskiy', 'santa ana', 'port alfred', 'yarmouth', 'tuktoyaktuk', 'kununurra', 'san policarpo', 'korgen', 'hithadhoo', 'pisco', 'gagra', 'p
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
units = "imperial"
query_url = f"{url}appid={weather_api}&units={units}&q="

# Set up list to hold reponses
responses = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    responses.append(response)

# %%
print(responses)
# Out:
# [{'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 44.15, 'feels_like': 38.98, 'temp_min': 44.15, 'temp_max': 44.15, 'pressure': 1009, 'humidity': 90, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 9.48, 'deg': 55, 'gust': 11.63}, 'clouds': {'all': 99}, 'dt': 1627462953, 'sys': {'country': 'CA', 'sunrise': 1627466876, 'sunset': 1627544947}, 'timezone': -21600, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}, {'coord': {'lon': 1.4078, 'lat': 18.4411}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 90.21, 'feels_like': 91.35, 'temp_min': 90.21, 'temp_max': 90.21, 'pressure': 1011, 'humidity': 41, 'sea_level': 1011, 'grnd_level': 961}, 'visibility': 10000, 'wind': {'speed': 9.95, 'deg': 204, 'gust': 9.46}, 'clouds': {'all': 96}, 'dt': 1627462953, '
# ...

# %%
# Dump responses into a DataFrame
raw_df = pd.json_normalize(responses)
raw_df
# Out:
#                                                weather      base  visibility  \
# 0    [{'id': 804, 'main': 'Clouds', 'description': ...  stations     10000.0
# 1    [{'id': 804, 'main': 'Clouds', 'description': ...  stations     10000.0
# 2    [{'id': 802, 'main': 'Clouds', 'description': ...  stations     10000.0
# 3    [{'id': 500, 'main': 'Rain', 'description': 'l...  stations     10000.0
# 4    [{'id': 500, 'main': 'Rain', 'description': 'l...  stations     10000.0
# ..                                                 ...       ...         ...
# 615  [{'id': 804, 'main': 'Clouds', 'description': ...  stations     10000.0
# 616  [{'id': 803, 'main': 'Clouds', 'description': ...  stations     10000.0
# 617  [{'id': 802, 'main': 'Clouds', 'description': ...  stations     10000.0
# 618  [{'id': 803, 'main': 'Clouds', 'description': ...  stations     10000.0
# 619  [{'id': 802, 'main': 'Clouds', 'description': ...  stations      9478.0
#
# ...

# %%
# Select columns
scatter_df = raw_df[['coord.lat', 'main.temp', 'main.humidity','clouds.all' ,'wind.speed']]
scatter_df.columns = ["Lattitude", "Tempreture (F)", "Humidity (%)", "Cloudiness (%)", "Wind Speed (mph)"]
scatter_clean = scatter_df.dropna()
scatter_clean
# Out:
#      Lattitude  Tempreture (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0      69.4541           44.15          90.0            99.0              9.48
# 1      18.4411           90.21          41.0            96.0              9.95
# 2      44.0787           55.60          94.0            30.0              3.29
# 3      32.2207           77.43          72.0             1.0              0.00
# 4      64.8378           54.28          95.0            90.0             12.66
# ..         ...             ...           ...             ...               ...
# 615    16.7167           78.60          93.0            99.0              6.98
# 616   -43.5333           47.97          82.0            75.0              1.99
# 617   -35.7167           55.98          68.0            47.0              6.35
# 618    46.4154           68.61          74.0            75.0              8.05
# 619   -15.4311           62.01          78.0            50.0              2.73
#
# [574 rows x 5 columns]

# %%
# Create a scatter plot which compares Temperature (F) vs. Latitude
scatter_clean.plot(kind="scatter", x="Lattitude", y="Tempreture (F)", figsize=(6,6), title="Temperature (F) vs. Latitude")
# Out:
# <AxesSubplot:title={'center':'Temperature (F) vs. Latitude'}, xlabel='Lattitude', ylabel='Tempreture (F)'>

# %%
# Create a scatter plot which compares Humidity (%) vs. Latitude
scatter_clean.plot(kind="scatter", x="Lattitude", y="Humidity (%)", figsize=(6,6), title="Humidity (%) vs. Latitude")
# Out:
# <AxesSubplot:title={'center':'Humidity (%) vs. Latitude'}, xlabel='Lattitude', ylabel='Humidity (%)'>

# %%
# Create a scatter plot which compares Cloudiness (%) vs. Latitude
scatter_clean.plot(kind="scatter", x="Lattitude", y="Cloudiness (%)", figsize=(6,6), title="Cloudiness (%) vs. Latitude")
# Out:
# <AxesSubplot:title={'center':'Cloudiness (%) vs. Latitude'}, xlabel='Lattitude', ylabel='Cloudiness (%)'>

# %%
# Create a scatter plot which compares Wind Speed (mph) vs. Latitude
scatter_clean.plot(kind="scatter", x="Lattitude", y="Wind Speed (mph)", figsize=(6,6), title="Wind Speed (mph) vs Latitude")
# Out:
# <AxesSubplot:title={'center':'Wind Speed (mph) vs Latitude'}, xlabel='Lattitude', ylabel='Wind Speed (mph)'>

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
